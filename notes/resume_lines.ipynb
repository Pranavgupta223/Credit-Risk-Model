# %% [markdown]
# # 🥇 Version 1 — Strong & Balanced (Recommended)
#
# > Built a cost-sensitive credit risk model using Logistic Regression with cross-validated threshold optimization, improving simulated portfolio outcome from -1.4M to +0.47M by aligning model decisions with economic assumptions (PD, LGD, EAD framework).
#
# ---
#
# # 🥈 Version 2 — More Technical
#
# > Developed a credit approval decision system using Logistic Regression with stratified cross-validation and out-of-fold probability calibration; implemented profit-based threshold tuning to maximize expected portfolio return under realistic interest and loss assumptions.
#
# ---
#
# # 🥉 Version 3 — More Business-Focused
#
# > Designed and evaluated a credit risk model using a champion–challenger framework (Logistic vs XGBoost), selecting the interpretable champion model and optimizing approval threshold to maximize expected financial return rather than classification accuracy.
#
# ---
#
# # 🧠 If Interviewer Asks You to Explain It
#
# You should say something like:
#
# > Instead of optimizing accuracy or AUC alone, I simulated loan economics by assigning profit to approved good customers and loss to approved defaulters. I used cross-validated probabilities to select the threshold that maximized expected portfolio profit. Logistic regression outperformed XGBoost in both AUC and stability, so it was selected as the deployable model.
#
# That answer shows:
#
# * Statistical understanding
# * Economic thinking
# * Model comparison maturity
# * Regulatory awareness
